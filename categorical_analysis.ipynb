# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('healthcare_data_v2.xlsx')

# %%
df.drop('keywords', axis=1)
# Out:
#      Unnamed: 0  serial_no        company  \
# 0             0          1     CitiusTech
# 1             1          2       Cureskin
# 2             2          3       Truemeds
# 3             3          4         Shipsy
# 4             4          5        Aknamed
# ..          ...        ...            ...
# 652         677        678         Petlet
# 653         678        679       McMarvin
# 654         680        681  Cranberry.Fit
# 655         681        682     VisionLabs
# 656         682        683        AI Vaid
#
#                                               overview      funding  \
# 0    Offers a range of analytical solutions and tec...  111250000.0
# 1    Developer of AI-driven app for automated diagn...   26837990.0
# 2    Online pharmacy for price comparison and purch...   27800897.0
# 3             AI powered logistics management software   36565391.0
# 4    Cloud and AI based material management softwar...   21926689.0
# ...

# %%
df['category'] = df['business_model'].str.split('>').str[0].str.strip()

# %%
unique_list = df['category'].unique().tolist()
print(unique_list)
# Out:
#      Unnamed: 0  serial_no        company  \
# 0             0          1     CitiusTech
# 1             1          2       Cureskin
# 2             2          3       Truemeds
# 3             3          4         Shipsy
# 4             4          5        Aknamed
# ..          ...        ...            ...
# 652         677        678         Petlet
# 653         678        679       McMarvin
# 654         680        681  Cranberry.Fit
# 655         681        682     VisionLabs
# 656         682        683        AI Vaid
#
#                                               overview      funding  \
# 0    Offers a range of analytical solutions and tec...  111250000.0
# 1    Developer of AI-driven app for automated diagn...   26837990.0
# 2    Online pharmacy for price comparison and purch...   27800897.0
# 3             AI powered logistics management software   36565391.0
# 4    Cloud and AI based material management softwar...   21926689.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
business_model_counts = df['category'].value_counts().reset_index()
business_model_counts.columns = ['business_model', 'company_count']

#Bar chart for counts
